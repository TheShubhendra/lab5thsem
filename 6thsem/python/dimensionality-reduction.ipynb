# %%
from sklearn.datasets import load_digits
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt

# %%
digits = load_digits()

# %%
tsne = TSNE(n_components=2,random_state=69)
reduced_data = tsne.fit_transform(digits.data)

# %%
reduced_data.shape
# Out:
# (1797, 2)

# %%
dots = plt.scatter(reduced_data[:,0], reduced_data[:, 1], c='black')

# %%
dots = plt.scatter(reduced_data[:,0], reduced_data[:, 1], c=digits.target, cmap=plt.cm.get_cmap('nipy_spectral_r', 10))
colorbar = plt.colorbar(dots)
# Out:
# /tmp/ipykernel_8019/534557006.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   dots = plt.scatter(reduced_data[:,0], reduced_data[:, 1], c=digits.target, cmap=plt.cm.get_cmap('nipy_spectral_r', 10))
