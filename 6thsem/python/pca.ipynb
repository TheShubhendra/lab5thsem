# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# %%
pca = PCA(n_components=2, random_state=11)

# %%
iris = load_iris()

# %%
pca.fit(iris.data)
# Out:
# PCA(n_components=2, random_state=11)

# %%
iris_pca = pca.transform(iris.data)

# %%
iris_pca.shape
# Out:
# (150, 2)

# %%
import pandas as pd

df  = pd.DataFrame(iris_pca, columns=["Component1", "Component2"])
df['species'] = [iris.target_names[i] for i in iris.target]

# %%
import seaborn as sns

axes = sns.scatterplot(data=df,x='Component1', y='Component2', hue='species', legend='brief', palette='cool')

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)
kmeans.fit(iris.data)
# Out:
# /home/student/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3)

# %%
centers = pca.transform(kmeans.cluster_centers_)

# %%
import matplotlib.pyplot as plt
axes = sns.scatterplot(data=df,x='Component1', y='Component2', hue='species', legend='brief', palette='cool')
dots = plt.scatter(centers[:,0], centers[:,1],s=100, c='k')
